# %%
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df=spark.read.format("json").load("/mnt/dlk/bronze/WEB/eurofxref/year=2021/month=10/day=20/time=2257/eurofxref.json",multiLine=True)
df.display()
#df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df=spark.read.format("json").load("/mnt/dlk/bronze/WEB/eurofxref/year=2021/month=10/day=20/time=2257/eurofxref.json",multiLine=True)
df.display()
#df.printSchema()
dbutils.fs.ls("dbfs:/mnt/dlk/silver/QAD")
df=spark.read.format("delta").load("dbfs:/mnt/dlk/silver/QAD/bom_mstr/")
df2=df.select("BronzeFileNameSource","BronzeFolderSource","IngestionDate")
display(df2)
df=spark.read.format("delta").load("dbfs:/mnt/dlk/silver/QAD/bom_mstr/")
df2=df.select("BronzeFileNameSource","BronzeFolderSource","IngestionDate")
display(df2)
Final.write.format("delta").mode("overwrite").option("overwriteSchema","true").save('/mnt/dlk/silver/WEB/eurofxref')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
