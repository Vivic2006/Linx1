# %% [markdown]
# Notebook qui centralise toutes les fonctions et classes du projet afin de faire qu'un seul %run dans un notebook.

# %%
# %run ./COMMON_VARIABLES

# %%
# %run ./COMMON_FUNCTIONS

# %%
#%run ./MONITOR

# %%
# %run ./LOADING_PARAMETERS

# %%
#%run ./CLEAN_DATA
